# %% [markdown]
# Following Medium article [A Gentle Introduction to Geospatial Data Science](https://medium.com/codex/a-gentle-introduction-to-geospatial-data-science-ce4291feb67d)

# %%
import geopandas as gpd

# %%
df = gpd.read_file("../data/unique_geocoded_matches/unique_geocoded_matches.shp")

# %%
df.head()
# Out:
#     Score             Match_addr                   LongLabel  \
# 0  100.00                  Wuhan                  Wuhan, CHN
# 1  100.00                  Hubei                  Hubei, CHN
# 2  100.00         Hubei, Jiangsu         Hubei, Jiangsu, CHN
# 3   78.18  The, Gilgit-Baltistan  The, Gilgit-Baltistan, PAK
# 4  100.00                  China                       China
#
#                 Type PlaceName  Rank            Region        RegionAbbr  \
# 0               City     Wuhan   2.5              None              None
# 1  State or Province     Hubei  14.5             Hubei             Hubei
# 2               City     Hubei  12.5           Jiangsu           Jiangsu
# 3               City       The  12.5  Gilgit-Baltistan  Gilgit-Baltistan
# 4            Country     China   1.5              None              None
#
#   Country LangCode  ...    DisplayX   DisplayY        Xmin        Xmax  \
# 0     CHN      WEN  ...  114.324720  30.643530  114.252720  114.396720
# ...

# %%
df.plot(figsize=(15,12))
# Out:
# <AxesSubplot:>
